# %% [markdown]
# # Проектная практика. Осень 2024.
# Исследование эффективности различных методов оптимизации при обучении
# PINN.

# %% [markdown]
# Уравнение теплопроводности: \\
#
# $$ \frac{\partial u}{\partial t} = \alpha \frac{\partial^2 u}{\partial x^2},\ x \in (0, L),\ t > 0 $$ \\
#
# Начальные условия: \\
#
# $$ \begin{cases}
# u(x, 0) = f(x), & x \in [0,L], \\
# u(0, t) = u(L, t) = 0, & t > 0.
# \end{cases}
#  $$

# %% [markdown]
# Задача: Реализовать PINN метод решения начально-краевой задачи для уравнения теплопроводности. Сравнить эффективность различных оптимизаторов
# (SGD, Adam, RMSprop, L-BFGS).

# %% [markdown]
# # Реализация обучения

# %%
import tensorflow as tf
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # 0 = all logs, 1 = filter out INFO, 2 = filter out WARNING, 3 = filter out ERROR
tf.get_logger().setLevel('ERROR')

# %% [markdown]
# Задаём данные

# %%
L = 1.0
alpha = 0.1

num_samples = 128  # плотность сетки

# t > 0 - пределы для t
start = 0.0
end = 1.0

# %%
import math

# начальная функция
def f(x):
  return tf.sin(tf.constant(math.pi) * x)

# %% [markdown]
# Составляем сетку. Выбираем случайные точки.

# %%
import numpy as np


# генерация датасета с нужными точками
def generate_data(count_points, x_val="random", t_val="random"):
  if x_val == "random" and t_val == "random":
    count = count_points ** 2
    repeat = count_points
  else:
    count = count_points
    repeat = 1

  if x_val == "random":
    x = np.linspace(0, L, count_points)
  else:
    x = np.ones(shape=(count, 1)) * x_val
  x = np.repeat(x, repeat)
  x = x.reshape(count, 1)

  if t_val == "random":
    t = np.linspace(start, end, count_points)
  else:
    t = np.ones(shape=(count, 1)) * t_val
  t = np.tile(t, repeat)
  t = t.reshape(count, 1)

  x = tf.convert_to_tensor(x, dtype=tf.float32)
  t = tf.convert_to_tensor(t, dtype=tf.float32)
  return x, t

# %%
physic_dataset = generate_data(count_points=num_samples)
initial_dataset = generate_data(count_points=num_samples**2, t_val=0)

x1, t1 = generate_data(count_points=num_samples**2, x_val=0)
x2, t2 = generate_data(count_points=num_samples**2, x_val=L)

x = tf.concat((x1, x2), axis=0)
t = tf.concat((t1, t2), axis=0)
boundary_dataset = x, t

# %% [markdown]
# Составляем лосс

# %% [markdown]
# $$ \mathcal{L}_{\text{physics}} = \frac{1}{N_{\text{physics}}} \sum_{i=1}^{N_{\text{physics}}} \left( \frac{\partial u}{\partial t} - \alpha \frac{\partial^2 u}{\partial x^2} \right)^2 $$ \\
# $$ \mathcal{L}_{\text{initial}} = \frac{1}{N_{\text{initial}}} \sum_{i=1}^{N_{\text{initial}}} \left( u(x_i, 0) - f(x_i) \right)^2 $$ \\
# $$ \mathcal{L}_{\text{boundary}} = \frac{1}{N_{\text{boundary}}} \sum_{i=1}^{N_{\text{boundary}}} \left( u(0, t_i) \right)^2 + \frac{1}{N_{\text{boundary}}} \sum_{i=1}^{N_{\text{boundary}}} \left( u(L, t_i) \right)^2 $$ \\

# %%
def initial_loss(model, x, t):
  data = tf.concat((x, t), axis=1)
  u_pred = model(data)
  loss = tf.reduce_mean(tf.square(u_pred - f(x)))
  return loss


def boundary_loss(model, x, t):
  data = tf.concat((x, t), axis=1)
  u_pred = model(data)
  loss = tf.reduce_mean(tf.square(u_pred))
  return loss


def physic_loss(model, x, t):
  with tf.GradientTape(persistent=True) as tape:
    tape.watch(x)
    tape.watch(t)

    data = tf.concat((x, t), axis=1)
    u_pred = model(data)

    u_t = tape.gradient(u_pred, t)

    u_x = tape.gradient(u_pred, x)
    u_xx = tape.gradient(u_x, x)

  loss = u_t - (alpha * u_xx)
  return tf.reduce_mean(tf.square(loss))

# %%
# шаг обучения
def step(model, physic, initial, boundary, optimizer):
  with tf.GradientTape() as tape:
    p_loss = physic_loss(model, physic[0], physic[1])

    b_loss = boundary_loss(model, boundary[0], boundary[1])

    i_loss = initial_loss(model, initial[0], initial[1])

    total_loss = p_loss + b_loss + i_loss

  gradients = tape.gradient(total_loss, model.trainable_variables)
  optimizer.apply_gradients(zip(gradients, model.trainable_variables))

  return p_loss, b_loss, i_loss

# процесс обучения
def train(model, physic, initial, boundary, optimizer, epochs):
  history = np.zeros(shape=(epochs, 3))

  best_vars = model.trainable_variables
  best_loss = float('inf')

  for i in range(1, epochs + 1):

    p_loss, b_loss, i_loss = step(model, physic, initial, boundary, optimizer)
    history[i - 1, 0] = p_loss
    history[i - 1, 1] = b_loss
    history[i - 1, 2] = i_loss

    total_loss = (p_loss + b_loss + i_loss).numpy()

    if total_loss < best_loss:
      best_loss = total_loss
      best_vars = model.trainable_variables

    if i % 50 == 0:
      print(f"Epoch {i}/{epochs}. Total loss: {total_loss:.6f}, Physic loss: {p_loss:.6f}, Boundary loss: {b_loss:.6f}, Initial loss: {i_loss:.6f}")

  return history, best_vars, best_loss

# %% [markdown]
# Строим модель и выбираем оптимизатор

# %%
from tensorflow.keras.layers import Input, Dense


optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
epochs = 6000

model = tf.keras.Sequential([ # создание модели
    Input(shape=(2, )),
    Dense(64, activation='tanh'),
    Dense(64, activation='tanh'),
    Dense(1)
])

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                      │ (None, 64)                  │             192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,417 (17.25 KB)
#  Trainable params: 4,417 (17.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ##Optimizer - Adam

# %% [markdown]
# Обучение

# %%
import time


curr = time.time() # засекаем время

history, best_vars, best_loss = train(model, physic_dataset, initial_dataset, boundary_dataset, optimizer, epochs)

print()
print(f"Model was training for {round(time.time() - curr)} seconds!")
print(f"The min loss is {best_loss:.6f}")
# Out:
# Epoch 50/6000. Total loss: 0.274973, Physic loss: 0.016975, Boundary loss: 0.074492, Initial loss: 0.183506
# Epoch 100/6000. Total loss: 0.272083, Physic loss: 0.017249, Boundary loss: 0.080644, Initial loss: 0.174190
# Epoch 150/6000. Total loss: 0.268029, Physic loss: 0.017316, Boundary loss: 0.079901, Initial loss: 0.170813
# Epoch 200/6000. Total loss: 0.258706, Physic loss: 0.018052, Boundary loss: 0.076310, Initial loss: 0.164344
# Epoch 250/6000. Total loss: 0.217790, Physic loss: 0.017075, Boundary loss: 0.062517, Initial loss: 0.138199
# Epoch 300/6000. Total loss: 0.119638, Physic loss: 0.017306, Boundary loss: 0.029883, Initial loss: 0.072449
# Epoch 350/6000. Total loss: 0.054981, Physic loss: 0.016304, Boundary loss: 0.011354, Initial loss: 0.027324
# Epoch 400/6000. Total loss: 0.036607, Physic loss: 0.013183, Boundary loss: 0.007315, Initial loss: 0.016109
# Epoch 450/6000. Total loss: 0.018817, Physic loss: 0.006654, Boundary loss: 0.003591, Initial loss: 0.008572
# Epoch 500/6000. Total loss: 0.009359, Physic loss: 0.004322, Boundary loss: 0.001554, Initial loss: 0.003483
# Epoch 550/6000. Total loss: 0.006949, Physic loss: 0.003492, Boundary loss: 0.001246, Initial loss: 0.002212
# Epoch 600/6000. Total loss: 0.005646, Physic loss: 0.002747, Boundary loss: 0.001156, Initial loss: 0.001742
# Epoch 650/6000. Total loss: 0.004586, Physic loss: 0.002081, Boundary loss: 0.001076, Initial loss: 0.001429
# Epoch 700/6000. Total loss: 0.003819, Physic loss: 0.001624, Boundary loss: 0.000995, Initial loss: 0.001199
# Epoch 750/6000. Total loss: 0.003281, Physic loss: 0.001334, Boundary loss: 0.000922, Initial loss: 0.001025
# Epoch 800/6000. Total loss: 0.002879, Physic loss: 0.001130, Boundary loss: 0.000860, Initial loss: 0.000889
# Epoch 850/6000. Total loss: 0.002557, Physic loss: 0.000969, Boundary loss: 0.000811, Initial loss: 0.000778
# Epoch 900/6000. Total loss: 0.002290, Physic loss: 0.000837, Boundary loss: 0.000767, Initial loss: 0.000685
# Epoch 950/6000. Total loss: 0.002068, Physic loss: 0.000738, Boundary loss: 0.000724, Initial loss: 0.000606
# Epoch 1000/6000. Total loss: 0.001885, Physic loss: 0.000668, Boundary loss: 0.000678, Initial loss: 0.000538
# Epoch 1050/6000. Total loss: 0.001731, Physic loss: 0.000621, Boundary loss: 0.000629, Initial loss: 0.000480
# Epoch 1100/6000. Total loss: 0.001597, Physic loss: 0.000588, Boundary loss: 0.000579, Initial loss: 0.000430
# Epoch 1150/6000. Total loss: 0.001478, Physic loss: 0.000562, Boundary loss: 0.000530, Initial loss: 0.000385
# Epoch 1200/6000. Total loss: 0.001371, Physic loss: 0.000540, Boundary loss: 0.000484, Initial loss: 0.000347
# Epoch 1250/6000. Total loss: 0.001275, Physic loss: 0.000519, Boundary loss: 0.000443, Initial loss: 0.000312
# Epoch 1300/6000. Total loss: 0.001187, Physic loss: 0.000499, Boundary loss: 0.000406, Initial loss: 0.000282
# Epoch 1350/6000. Total loss: 0.001197, Physic loss: 0.000540, Boundary loss: 0.000382, Initial loss: 0.000276
# Epoch 1400/6000. Total loss: 0.001047, Physic loss: 0.000458, Boundary loss: 0.000352, Initial loss: 0.000237
# Epoch 1450/6000. Total loss: 0.000989, Physic loss: 0.000442, Boundary loss: 0.000328, Initial loss: 0.000219
# Epoch 1500/6000. Total loss: 0.000937, Physic loss: 0.000426, Boundary loss: 0.000308, Initial loss: 0.000203
# Epoch 1550/6000. Total loss: 0.000891, Physic loss: 0.000413, Boundary loss: 0.000289, Initial loss: 0.000189
# Epoch 1600/6000. Total loss: 0.001316, Physic loss: 0.000605, Boundary loss: 0.000449, Initial loss: 0.000262
# Epoch 1650/6000. Total loss: 0.000818, Physic loss: 0.000394, Boundary loss: 0.000257, Initial loss: 0.000167
# Epoch 1700/6000. Total loss: 0.000785, Physic loss: 0.000380, Boundary loss: 0.000247, Initial loss: 0.000158
# Epoch 1750/6000. Total loss: 0.000756, Physic loss: 0.000371, Boundary loss: 0.000235, Initial loss: 0.000149
# Epoch 1800/6000. Total loss: 0.000728, Physic loss: 0.000363, Boundary loss: 0.000224, Initial loss: 0.000141
# Epoch 1850/6000. Total loss: 0.001448, Physic loss: 0.000535, Boundary loss: 0.000612, Initial loss: 0.000302
# Epoch 1900/6000. Total loss: 0.000681, Physic loss: 0.000346, Boundary loss: 0.000206, Initial loss: 0.000129
# Epoch 1950/6000. Total loss: 0.000659, Physic loss: 0.000339, Boundary loss: 0.000197, Initial loss: 0.000123
# Epoch 2000/6000. Total loss: 0.000638, Physic loss: 0.000332, Boundary loss: 0.000189, Initial loss: 0.000118
# Epoch 2050/6000. Total loss: 0.000618, Physic loss: 0.000324, Boundary loss: 0.000181, Initial loss: 0.000113
# Epoch 2100/6000. Total loss: 0.000599, Physic loss: 0.000315, Boundary loss: 0.000175, Initial loss: 0.000109
# Epoch 2150/6000. Total loss: 0.000600, Physic loss: 0.000321, Boundary loss: 0.000173, Initial loss: 0.000106
# Epoch 2200/6000. Total loss: 0.000563, Physic loss: 0.000302, Boundary loss: 0.000161, Initial loss: 0.000100
# Epoch 2250/6000. Total loss: 0.000546, Physic loss: 0.000294, Boundary loss: 0.000155, Initial loss: 0.000097
# Epoch 2300/6000. Total loss: 0.000529, Physic loss: 0.000287, Boundary loss: 0.000149, Initial loss: 0.000093
# Epoch 2350/6000. Total loss: 0.000512, Physic loss: 0.000280, Boundary loss: 0.000143, Initial loss: 0.000089
# Epoch 2400/6000. Total loss: 0.000688, Physic loss: 0.000346, Boundary loss: 0.000222, Initial loss: 0.000120
# Epoch 2450/6000. Total loss: 0.000482, Physic loss: 0.000266, Boundary loss: 0.000133, Initial loss: 0.000083
# Epoch 2500/6000. Total loss: 0.000467, Physic loss: 0.000259, Boundary loss: 0.000128, Initial loss: 0.000080
# Epoch 2550/6000. Total loss: 0.000453, Physic loss: 0.000253, Boundary loss: 0.000123, Initial loss: 0.000077
# Epoch 2600/6000. Total loss: 0.000438, Physic loss: 0.000246, Boundary loss: 0.000118, Initial loss: 0.000074
# Epoch 2650/6000. Total loss: 0.000424, Physic loss: 0.000239, Boundary loss: 0.000114, Initial loss: 0.000072
# Epoch 2700/6000. Total loss: 0.000411, Physic loss: 0.000233, Boundary loss: 0.000109, Initial loss: 0.000069
# Epoch 2750/6000. Total loss: 0.000398, Physic loss: 0.000226, Boundary loss: 0.000105, Initial loss: 0.000067
# Epoch 2800/6000. Total loss: 0.000386, Physic loss: 0.000220, Boundary loss: 0.000101, Initial loss: 0.000064
# Epoch 2850/6000. Total loss: 0.000373, Physic loss: 0.000213, Boundary loss: 0.000098, Initial loss: 0.000062
# Epoch 2900/6000. Total loss: 0.000360, Physic loss: 0.000207, Boundary loss: 0.000094, Initial loss: 0.000060
# Epoch 2950/6000. Total loss: 0.000503, Physic loss: 0.000253, Boundary loss: 0.000163, Initial loss: 0.000086
# Epoch 3000/6000. Total loss: 0.000338, Physic loss: 0.000194, Boundary loss: 0.000088, Initial loss: 0.000057
# Epoch 3050/6000. Total loss: 0.000326, Physic loss: 0.000188, Boundary loss: 0.000084, Initial loss: 0.000054
# Epoch 3100/6000. Total loss: 0.000315, Physic loss: 0.000182, Boundary loss: 0.000081, Initial loss: 0.000052
# Epoch 3150/6000. Total loss: 0.000304, Physic loss: 0.000176, Boundary loss: 0.000078, Initial loss: 0.000050
# Epoch 3200/6000. Total loss: 0.000293, Physic loss: 0.000170, Boundary loss: 0.000075, Initial loss: 0.000047
# Epoch 3250/6000. Total loss: 0.000582, Physic loss: 0.000258, Boundary loss: 0.000216, Initial loss: 0.000108
# Epoch 3300/6000. Total loss: 0.000274, Physic loss: 0.000160, Boundary loss: 0.000070, Initial loss: 0.000044
# Epoch 3350/6000. Total loss: 0.000264, Physic loss: 0.000154, Boundary loss: 0.000067, Initial loss: 0.000042
# Epoch 3400/6000. Total loss: 0.000255, Physic loss: 0.000149, Boundary loss: 0.000065, Initial loss: 0.000041
# Epoch 3450/6000. Total loss: 0.000246, Physic loss: 0.000145, Boundary loss: 0.000062, Initial loss: 0.000039
# Epoch 3500/6000. Total loss: 0.000237, Physic loss: 0.000140, Boundary loss: 0.000060, Initial loss: 0.000037
# Epoch 3550/6000. Total loss: 0.000257, Physic loss: 0.000147, Boundary loss: 0.000071, Initial loss: 0.000039
# Epoch 3600/6000. Total loss: 0.000222, Physic loss: 0.000132, Boundary loss: 0.000056, Initial loss: 0.000034
# Epoch 3650/6000. Total loss: 0.000215, Physic loss: 0.000128, Boundary loss: 0.000054, Initial loss: 0.000033
# Epoch 3700/6000. Total loss: 0.000208, Physic loss: 0.000125, Boundary loss: 0.000052, Initial loss: 0.000032
# Epoch 3750/6000. Total loss: 0.000201, Physic loss: 0.000121, Boundary loss: 0.000050, Initial loss: 0.000031
# Epoch 3800/6000. Total loss: 0.000194, Physic loss: 0.000117, Boundary loss: 0.000048, Initial loss: 0.000029
# Epoch 3850/6000. Total loss: 0.000268, Physic loss: 0.000131, Boundary loss: 0.000081, Initial loss: 0.000056
# Epoch 3900/6000. Total loss: 0.000183, Physic loss: 0.000111, Boundary loss: 0.000044, Initial loss: 0.000027
# Epoch 3950/6000. Total loss: 0.000177, Physic loss: 0.000108, Boundary loss: 0.000043, Initial loss: 0.000027
# Epoch 4000/6000. Total loss: 0.000171, Physic loss: 0.000104, Boundary loss: 0.000041, Initial loss: 0.000026
# Epoch 4050/6000. Total loss: 0.000165, Physic loss: 0.000101, Boundary loss: 0.000040, Initial loss: 0.000025
# Epoch 4100/6000. Total loss: 0.000160, Physic loss: 0.000098, Boundary loss: 0.000038, Initial loss: 0.000024
# Epoch 4150/6000. Total loss: 0.002275, Physic loss: 0.000648, Boundary loss: 0.001024, Initial loss: 0.000603
# Epoch 4200/6000. Total loss: 0.000154, Physic loss: 0.000095, Boundary loss: 0.000037, Initial loss: 0.000022
# Epoch 4250/6000. Total loss: 0.000145, Physic loss: 0.000090, Boundary loss: 0.000034, Initial loss: 0.000021
# Epoch 4300/6000. Total loss: 0.000141, Physic loss: 0.000088, Boundary loss: 0.000032, Initial loss: 0.000021
# Epoch 4350/6000. Total loss: 0.000136, Physic loss: 0.000085, Boundary loss: 0.000031, Initial loss: 0.000020
# Epoch 4400/6000. Total loss: 0.000132, Physic loss: 0.000083, Boundary loss: 0.000030, Initial loss: 0.000019
# Epoch 4450/6000. Total loss: 0.000128, Physic loss: 0.000081, Boundary loss: 0.000028, Initial loss: 0.000018
# Epoch 4500/6000. Total loss: 0.000243, Physic loss: 0.000106, Boundary loss: 0.000080, Initial loss: 0.000056
# Epoch 4550/6000. Total loss: 0.000121, Physic loss: 0.000078, Boundary loss: 0.000026, Initial loss: 0.000017
# Epoch 4600/6000. Total loss: 0.000117, Physic loss: 0.000076, Boundary loss: 0.000025, Initial loss: 0.000016
# Epoch 4650/6000. Total loss: 0.000114, Physic loss: 0.000074, Boundary loss: 0.000024, Initial loss: 0.000016
# Epoch 4700/6000. Total loss: 0.000111, Physic loss: 0.000073, Boundary loss: 0.000023, Initial loss: 0.000015
# Epoch 4750/6000. Total loss: 0.000107, Physic loss: 0.000071, Boundary loss: 0.000022, Initial loss: 0.000014
# Epoch 4800/6000. Total loss: 0.000414, Physic loss: 0.000144, Boundary loss: 0.000168, Initial loss: 0.000102
# Epoch 4850/6000. Total loss: 0.000113, Physic loss: 0.000071, Boundary loss: 0.000024, Initial loss: 0.000017
# Epoch 4900/6000. Total loss: 0.000100, Physic loss: 0.000069, Boundary loss: 0.000019, Initial loss: 0.000013
# Epoch 4950/6000. Total loss: 0.000098, Physic loss: 0.000067, Boundary loss: 0.000018, Initial loss: 0.000012
# Epoch 5000/6000. Total loss: 0.000096, Physic loss: 0.000066, Boundary loss: 0.000017, Initial loss: 0.000012
# Epoch 5050/6000. Total loss: 0.000093, Physic loss: 0.000065, Boundary loss: 0.000017, Initial loss: 0.000011
# Epoch 5100/6000. Total loss: 0.000091, Physic loss: 0.000064, Boundary loss: 0.000016, Initial loss: 0.000011
# Epoch 5150/6000. Total loss: 0.000089, Physic loss: 0.000063, Boundary loss: 0.000015, Initial loss: 0.000011
# Epoch 5200/6000. Total loss: 0.000097, Physic loss: 0.000065, Boundary loss: 0.000019, Initial loss: 0.000014
# Epoch 5250/6000. Total loss: 0.000085, Physic loss: 0.000062, Boundary loss: 0.000014, Initial loss: 0.000010
# Epoch 5300/6000. Total loss: 0.000083, Physic loss: 0.000061, Boundary loss: 0.000013, Initial loss: 0.000009
# Epoch 5350/6000. Total loss: 0.000081, Physic loss: 0.000060, Boundary loss: 0.000012, Initial loss: 0.000009
# Epoch 5400/6000. Total loss: 0.000079, Physic loss: 0.000059, Boundary loss: 0.000012, Initial loss: 0.000009
# Epoch 5450/6000. Total loss: 0.000078, Physic loss: 0.000058, Boundary loss: 0.000011, Initial loss: 0.000008
# Epoch 5500/6000. Total loss: 0.000094, Physic loss: 0.000062, Boundary loss: 0.000019, Initial loss: 0.000013
# Epoch 5550/6000. Total loss: 0.000084, Physic loss: 0.000061, Boundary loss: 0.000014, Initial loss: 0.000009
# Epoch 5600/6000. Total loss: 0.000073, Physic loss: 0.000056, Boundary loss: 0.000010, Initial loss: 0.000007
# Epoch 5650/6000. Total loss: 0.000072, Physic loss: 0.000055, Boundary loss: 0.000009, Initial loss: 0.000007
# Epoch 5700/6000. Total loss: 0.000070, Physic loss: 0.000055, Boundary loss: 0.000009, Initial loss: 0.000007
# Epoch 5750/6000. Total loss: 0.000069, Physic loss: 0.000054, Boundary loss: 0.000008, Initial loss: 0.000007
# Epoch 5800/6000. Total loss: 0.000067, Physic loss: 0.000053, Boundary loss: 0.000008, Initial loss: 0.000006
# Epoch 5850/6000. Total loss: 0.000545, Physic loss: 0.000226, Boundary loss: 0.000215, Initial loss: 0.000105
# Epoch 5900/6000. Total loss: 0.000066, Physic loss: 0.000052, Boundary loss: 0.000008, Initial loss: 0.000006
# Epoch 5950/6000. Total loss: 0.000064, Physic loss: 0.000051, Boundary loss: 0.000007, Initial loss: 0.000006
# Epoch 6000/6000. Total loss: 0.000063, Physic loss: 0.000050, Boundary loss: 0.000007, Initial loss: 0.000006
#
# Model was training for 455 seconds!
# The min loss is 0.000063

# %% [markdown]
# График loss

# %%
import matplotlib.pyplot as plt


epochs_arr = np.arange(0, epochs)
start_epoch = 0 # с какой эпохи смотреть график

plt.plot(epochs_arr[start_epoch:], np.log10(np.sum(history[start_epoch:], axis=1)))
plt.show()

# %% [markdown]
# Выбираем лучшую модель

# %%
model.set_weights(best_vars)

# %% [markdown]
# Тестирование

# %%
# создаём новые точки

num_samples = 10000

x = np.random.uniform(0.0, L, size=(num_samples, 1))
t = np.random.uniform(start, end, size=(num_samples, 1))

x_test = tf.convert_to_tensor(x, dtype=tf.float32)
t_test = tf.convert_to_tensor(t, dtype=tf.float32)

# %% [markdown]
# Графики

# %%
u_pred = model(tf.concat([x, t], axis=1)).numpy()

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x, t, u_pred)

ax.set_xlabel('x axis')
ax.set_ylabel('t axis')
ax.set_zlabel('u axis')

plt.show()

# %% [markdown]
# **Правильное решение**

# %% [markdown]
# $$ u(x, t) = \sin(\pi x)e^{-\alpha \pi^2 t} $$

# %%
u = np.sin(np.pi * x) * np.exp((-alpha * (np.pi ** 2)) * t)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x, t, u)

ax.set_xlabel('x axis')
ax.set_ylabel('t axis')
ax.set_zlabel('u axis')

plt.show()

# %% [markdown]
# Подсчёт MAE (сравниваем с правильным решением)

# %%
print(f"MAE: {np.mean(np.abs(u - u_pred))}")
# Out:
# MAE: 0.0007730602819766478

# %% [markdown]
# ## Подытог обучения модели с помощью Adam
#
# За 6000 эпох:
#
# *   train total loss: 0.000063
# *   test MAE: 0.0007730602819766478

# %% [markdown]
# ## Optimizer - SGD

# %%
import time


optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.001)
curr = time.time() # засекаем время

history, best_vars, best_loss = train(model, physic_dataset, initial_dataset, boundary_dataset, optimizer, epochs)

print()
print(f"Model was training for {round((time.time() - curr) / 60)} minutes!")
print(f"The min loss is {best_loss:.6f}")
# Out:
# Epoch 50/6000. Total loss: 0.272247, Physic loss: 0.006630, Boundary loss: 0.106422, Initial loss: 0.159195
# Epoch 100/6000. Total loss: 0.249745, Physic loss: 0.007329, Boundary loss: 0.102868, Initial loss: 0.139548
# Epoch 150/6000. Total loss: 0.190711, Physic loss: 0.005203, Boundary loss: 0.077634, Initial loss: 0.107873
# Epoch 200/6000. Total loss: 0.118582, Physic loss: 0.011794, Boundary loss: 0.049884, Initial loss: 0.056904
# Epoch 250/6000. Total loss: 0.086882, Physic loss: 0.020392, Boundary loss: 0.030888, Initial loss: 0.035602
# Epoch 300/6000. Total loss: 0.063993, Physic loss: 0.015171, Boundary loss: 0.028150, Initial loss: 0.020671
# Epoch 350/6000. Total loss: 0.050623, Physic loss: 0.018290, Boundary loss: 0.016922, Initial loss: 0.015411
# Epoch 400/6000. Total loss: 0.039812, Physic loss: 0.011800, Boundary loss: 0.018272, Initial loss: 0.009741
# Epoch 450/6000. Total loss: 0.027668, Physic loss: 0.010961, Boundary loss: 0.009707, Initial loss: 0.007000
# Epoch 500/6000. Total loss: 0.020456, Physic loss: 0.007324, Boundary loss: 0.008472, Initial loss: 0.004659
# Epoch 550/6000. Total loss: 0.018039, Physic loss: 0.006862, Boundary loss: 0.007399, Initial loss: 0.003778
# Epoch 600/6000. Total loss: 0.018344, Physic loss: 0.008483, Boundary loss: 0.006676, Initial loss: 0.003185
# Epoch 650/6000. Total loss: 0.018775, Physic loss: 0.004738, Boundary loss: 0.009718, Initial loss: 0.004318
# Epoch 700/6000. Total loss: 0.017553, Physic loss: 0.008875, Boundary loss: 0.006129, Initial loss: 0.002549
# Epoch 750/6000. Total loss: 0.015928, Physic loss: 0.003536, Boundary loss: 0.008455, Initial loss: 0.003938
# Epoch 800/6000. Total loss: 0.014386, Physic loss: 0.007351, Boundary loss: 0.004920, Initial loss: 0.002116
# Epoch 850/6000. Total loss: 0.013983, Physic loss: 0.002976, Boundary loss: 0.007370, Initial loss: 0.003636
# Epoch 900/6000. Total loss: 0.014132, Physic loss: 0.007355, Boundary loss: 0.004766, Initial loss: 0.002011
# Epoch 950/6000. Total loss: 0.014759, Physic loss: 0.002664, Boundary loss: 0.007951, Initial loss: 0.004144
# Epoch 1000/6000. Total loss: 0.014573, Physic loss: 0.007387, Boundary loss: 0.005096, Initial loss: 0.002090
# Epoch 1050/6000. Total loss: 0.011174, Physic loss: 0.002637, Boundary loss: 0.005542, Initial loss: 0.002995
# Epoch 1100/6000. Total loss: 0.007859, Physic loss: 0.003149, Boundary loss: 0.003047, Initial loss: 0.001663
# Epoch 1150/6000. Total loss: 0.006779, Physic loss: 0.003076, Boundary loss: 0.002307, Initial loss: 0.001396
# Epoch 1200/6000. Total loss: 0.008677, Physic loss: 0.002050, Boundary loss: 0.004284, Initial loss: 0.002342
# Epoch 1250/6000. Total loss: 0.013849, Physic loss: 0.007082, Boundary loss: 0.004784, Initial loss: 0.001983
# Epoch 1300/6000. Total loss: 0.007762, Physic loss: 0.002213, Boundary loss: 0.003533, Initial loss: 0.002016
# Epoch 1350/6000. Total loss: 0.005912, Physic loss: 0.001818, Boundary loss: 0.002602, Initial loss: 0.001492
# Epoch 1400/6000. Total loss: 0.011747, Physic loss: 0.005965, Boundary loss: 0.004022, Initial loss: 0.001760
# Epoch 1450/6000. Total loss: 0.006734, Physic loss: 0.001956, Boundary loss: 0.003029, Initial loss: 0.001749
# Epoch 1500/6000. Total loss: 0.006055, Physic loss: 0.001536, Boundary loss: 0.002905, Initial loss: 0.001614
# Epoch 1550/6000. Total loss: 0.011148, Physic loss: 0.005147, Boundary loss: 0.004152, Initial loss: 0.001849
# Epoch 1600/6000. Total loss: 0.004724, Physic loss: 0.002179, Boundary loss: 0.001563, Initial loss: 0.000981
# Epoch 1650/6000. Total loss: 0.011156, Physic loss: 0.001510, Boundary loss: 0.006150, Initial loss: 0.003496
# Epoch 1700/6000. Total loss: 0.004884, Physic loss: 0.001271, Boundary loss: 0.002337, Initial loss: 0.001276
# Epoch 1750/6000. Total loss: 0.005563, Physic loss: 0.002058, Boundary loss: 0.002274, Initial loss: 0.001231
# Epoch 1800/6000. Total loss: 0.011925, Physic loss: 0.005724, Boundary loss: 0.004364, Initial loss: 0.001836
# Epoch 1850/6000. Total loss: 0.004158, Physic loss: 0.001961, Boundary loss: 0.001362, Initial loss: 0.000835
# Epoch 1900/6000. Total loss: 0.010162, Physic loss: 0.002059, Boundary loss: 0.004534, Initial loss: 0.003569
# Epoch 1950/6000. Total loss: 0.011737, Physic loss: 0.003590, Boundary loss: 0.005367, Initial loss: 0.002780
# Epoch 2000/6000. Total loss: 0.006700, Physic loss: 0.003054, Boundary loss: 0.002523, Initial loss: 0.001123
# Epoch 2050/6000. Total loss: 0.003613, Physic loss: 0.001410, Boundary loss: 0.001107, Initial loss: 0.001096
# Epoch 2100/6000. Total loss: 0.004138, Physic loss: 0.001253, Boundary loss: 0.002039, Initial loss: 0.000846
# Epoch 2150/6000. Total loss: 0.009318, Physic loss: 0.000798, Boundary loss: 0.004418, Initial loss: 0.004102
# Epoch 2200/6000. Total loss: 0.004229, Physic loss: 0.001694, Boundary loss: 0.001661, Initial loss: 0.000874
# Epoch 2250/6000. Total loss: 0.002602, Physic loss: 0.001114, Boundary loss: 0.000915, Initial loss: 0.000574
# Epoch 2300/6000. Total loss: 0.009072, Physic loss: 0.000757, Boundary loss: 0.004308, Initial loss: 0.004007
# Epoch 2350/6000. Total loss: 0.003505, Physic loss: 0.000847, Boundary loss: 0.001283, Initial loss: 0.001374
# Epoch 2400/6000. Total loss: 0.014013, Physic loss: 0.004028, Boundary loss: 0.005873, Initial loss: 0.004111
# Epoch 2450/6000. Total loss: 0.003178, Physic loss: 0.001407, Boundary loss: 0.001182, Initial loss: 0.000588
# Epoch 2500/6000. Total loss: 0.009375, Physic loss: 0.000730, Boundary loss: 0.004495, Initial loss: 0.004149
# Epoch 2550/6000. Total loss: 0.003511, Physic loss: 0.000886, Boundary loss: 0.001304, Initial loss: 0.001321
# Epoch 2600/6000. Total loss: 0.008928, Physic loss: 0.001625, Boundary loss: 0.003900, Initial loss: 0.003403
# Epoch 2650/6000. Total loss: 0.002199, Physic loss: 0.000958, Boundary loss: 0.000765, Initial loss: 0.000476
# Epoch 2700/6000. Total loss: 0.004613, Physic loss: 0.002093, Boundary loss: 0.001751, Initial loss: 0.000769
# Epoch 2750/6000. Total loss: 0.004119, Physic loss: 0.000587, Boundary loss: 0.001717, Initial loss: 0.001815
# Epoch 2800/6000. Total loss: 0.001995, Physic loss: 0.000590, Boundary loss: 0.000646, Initial loss: 0.000758
# Epoch 2850/6000. Total loss: 0.004721, Physic loss: 0.001340, Boundary loss: 0.001869, Initial loss: 0.001512
# Epoch 2900/6000. Total loss: 0.003357, Physic loss: 0.001153, Boundary loss: 0.001166, Initial loss: 0.001038
# Epoch 2950/6000. Total loss: 0.002840, Physic loss: 0.000608, Boundary loss: 0.001045, Initial loss: 0.001186
# Epoch 3000/6000. Total loss: 0.011327, Physic loss: 0.002467, Boundary loss: 0.004860, Initial loss: 0.004000
# Epoch 3050/6000. Total loss: 0.002062, Physic loss: 0.000551, Boundary loss: 0.001058, Initial loss: 0.000452
# Epoch 3100/6000. Total loss: 0.005413, Physic loss: 0.001680, Boundary loss: 0.002777, Initial loss: 0.000955
# Epoch 3150/6000. Total loss: 0.004469, Physic loss: 0.001275, Boundary loss: 0.001738, Initial loss: 0.001456
# Epoch 3200/6000. Total loss: 0.001858, Physic loss: 0.000876, Boundary loss: 0.000633, Initial loss: 0.000348
# Epoch 3250/6000. Total loss: 0.006964, Physic loss: 0.002796, Boundary loss: 0.002924, Initial loss: 0.001244
# Epoch 3300/6000. Total loss: 0.002199, Physic loss: 0.000854, Boundary loss: 0.000722, Initial loss: 0.000622
# Epoch 3350/6000. Total loss: 0.003657, Physic loss: 0.000579, Boundary loss: 0.002130, Initial loss: 0.000948
# Epoch 3400/6000. Total loss: 0.002105, Physic loss: 0.000654, Boundary loss: 0.000734, Initial loss: 0.000717
# Epoch 3450/6000. Total loss: 0.007243, Physic loss: 0.000540, Boundary loss: 0.003386, Initial loss: 0.003318
# Epoch 3500/6000. Total loss: 0.003409, Physic loss: 0.000649, Boundary loss: 0.001988, Initial loss: 0.000772
# Epoch 3550/6000. Total loss: 0.006581, Physic loss: 0.000699, Boundary loss: 0.002991, Initial loss: 0.002892
# Epoch 3600/6000. Total loss: 0.002230, Physic loss: 0.001001, Boundary loss: 0.000791, Initial loss: 0.000438
# Epoch 3650/6000. Total loss: 0.005451, Physic loss: 0.000784, Boundary loss: 0.003106, Initial loss: 0.001562
# Epoch 3700/6000. Total loss: 0.003701, Physic loss: 0.001567, Boundary loss: 0.001397, Initial loss: 0.000737
# Epoch 3750/6000. Total loss: 0.007799, Physic loss: 0.002560, Boundary loss: 0.003610, Initial loss: 0.001630
# Epoch 3800/6000. Total loss: 0.002916, Physic loss: 0.001239, Boundary loss: 0.001050, Initial loss: 0.000627
# Epoch 3850/6000. Total loss: 0.003780, Physic loss: 0.000930, Boundary loss: 0.001422, Initial loss: 0.001428
# Epoch 3900/6000. Total loss: 0.003509, Physic loss: 0.000815, Boundary loss: 0.001975, Initial loss: 0.000718
# Epoch 3950/6000. Total loss: 0.009118, Physic loss: 0.000493, Boundary loss: 0.004542, Initial loss: 0.004083
# Epoch 4000/6000. Total loss: 0.002759, Physic loss: 0.001118, Boundary loss: 0.001061, Initial loss: 0.000580
# Epoch 4050/6000. Total loss: 0.006477, Physic loss: 0.000847, Boundary loss: 0.003679, Initial loss: 0.001951
# Epoch 4100/6000. Total loss: 0.003542, Physic loss: 0.001449, Boundary loss: 0.001366, Initial loss: 0.000728
# Epoch 4150/6000. Total loss: 0.005883, Physic loss: 0.000909, Boundary loss: 0.003323, Initial loss: 0.001652
# Epoch 4200/6000. Total loss: 0.001594, Physic loss: 0.000490, Boundary loss: 0.000595, Initial loss: 0.000509
# Epoch 4250/6000. Total loss: 0.005328, Physic loss: 0.000440, Boundary loss: 0.002500, Initial loss: 0.002387
# Epoch 4300/6000. Total loss: 0.005465, Physic loss: 0.000604, Boundary loss: 0.003220, Initial loss: 0.001641
# Epoch 4350/6000. Total loss: 0.003194, Physic loss: 0.001274, Boundary loss: 0.001242, Initial loss: 0.000678
# Epoch 4400/6000. Total loss: 0.002441, Physic loss: 0.000542, Boundary loss: 0.001399, Initial loss: 0.000501
# Epoch 4450/6000. Total loss: 0.005555, Physic loss: 0.000402, Boundary loss: 0.002791, Initial loss: 0.002361
# Epoch 4500/6000. Total loss: 0.002866, Physic loss: 0.000959, Boundary loss: 0.001178, Initial loss: 0.000730
# Epoch 4550/6000. Total loss: 0.002898, Physic loss: 0.000507, Boundary loss: 0.001628, Initial loss: 0.000763
# Epoch 4600/6000. Total loss: 0.001943, Physic loss: 0.000749, Boundary loss: 0.000831, Initial loss: 0.000364
# Epoch 4650/6000. Total loss: 0.002596, Physic loss: 0.000798, Boundary loss: 0.000975, Initial loss: 0.000824
# Epoch 4700/6000. Total loss: 0.002733, Physic loss: 0.001033, Boundary loss: 0.001225, Initial loss: 0.000475
# Epoch 4750/6000. Total loss: 0.003912, Physic loss: 0.001350, Boundary loss: 0.001794, Initial loss: 0.000768
# Epoch 4800/6000. Total loss: 0.004574, Physic loss: 0.001265, Boundary loss: 0.001702, Initial loss: 0.001607
# Epoch 4850/6000. Total loss: 0.002315, Physic loss: 0.000732, Boundary loss: 0.000814, Initial loss: 0.000770
# Epoch 4900/6000. Total loss: 0.003739, Physic loss: 0.000385, Boundary loss: 0.002294, Initial loss: 0.001059
# Epoch 4950/6000. Total loss: 0.001421, Physic loss: 0.000426, Boundary loss: 0.000735, Initial loss: 0.000260
# Epoch 5000/6000. Total loss: 0.002844, Physic loss: 0.000457, Boundary loss: 0.001277, Initial loss: 0.001109
# Epoch 5050/6000. Total loss: 0.002820, Physic loss: 0.000402, Boundary loss: 0.001162, Initial loss: 0.001256
# Epoch 5100/6000. Total loss: 0.006610, Physic loss: 0.000513, Boundary loss: 0.004249, Initial loss: 0.001848
# Epoch 5150/6000. Total loss: 0.001869, Physic loss: 0.000670, Boundary loss: 0.000889, Initial loss: 0.000309
# Epoch 5200/6000. Total loss: 0.002062, Physic loss: 0.000694, Boundary loss: 0.000817, Initial loss: 0.000550
# Epoch 5250/6000. Total loss: 0.003129, Physic loss: 0.000410, Boundary loss: 0.001311, Initial loss: 0.001408
# Epoch 5300/6000. Total loss: 0.002476, Physic loss: 0.000706, Boundary loss: 0.001058, Initial loss: 0.000712
# Epoch 5350/6000. Total loss: 0.004463, Physic loss: 0.000986, Boundary loss: 0.002080, Initial loss: 0.001396
# Epoch 5400/6000. Total loss: 0.003882, Physic loss: 0.000383, Boundary loss: 0.002498, Initial loss: 0.001002
# Epoch 5450/6000. Total loss: 0.004730, Physic loss: 0.000398, Boundary loss: 0.002938, Initial loss: 0.001394
# Epoch 5500/6000. Total loss: 0.004543, Physic loss: 0.000367, Boundary loss: 0.002842, Initial loss: 0.001335
# Epoch 5550/6000. Total loss: 0.002173, Physic loss: 0.000795, Boundary loss: 0.000872, Initial loss: 0.000506
# Epoch 5600/6000. Total loss: 0.001652, Physic loss: 0.000332, Boundary loss: 0.000602, Initial loss: 0.000717
# Epoch 5650/6000. Total loss: 0.001887, Physic loss: 0.000307, Boundary loss: 0.000733, Initial loss: 0.000847
# Epoch 5700/6000. Total loss: 0.002863, Physic loss: 0.000803, Boundary loss: 0.001452, Initial loss: 0.000608
# Epoch 5750/6000. Total loss: 0.002937, Physic loss: 0.000645, Boundary loss: 0.001573, Initial loss: 0.000718
# Epoch 5800/6000. Total loss: 0.002637, Physic loss: 0.000244, Boundary loss: 0.001698, Initial loss: 0.000695
# Epoch 5850/6000. Total loss: 0.002281, Physic loss: 0.000775, Boundary loss: 0.001042, Initial loss: 0.000464
# Epoch 5900/6000. Total loss: 0.003894, Physic loss: 0.000460, Boundary loss: 0.001925, Initial loss: 0.001509
# Epoch 5950/6000. Total loss: 0.004497, Physic loss: 0.000370, Boundary loss: 0.002036, Initial loss: 0.002091
# Epoch 6000/6000. Total loss: 0.003302, Physic loss: 0.000316, Boundary loss: 0.001516, Initial loss: 0.001470
#
# Model was training for 6 minutes!
# The min loss is 0.000902

# %%
import matplotlib.pyplot as plt


epochs_arr = np.arange(0, epochs)
start_epoch = 0 # с какой эпохи смотреть график

plt.plot(epochs_arr[start_epoch:], np.log10(np.sum(history[start_epoch:], axis=1)))
plt.show()

# %%
model.set_weights(best_vars)

# %%
# создаём новые точки

num_samples = 10000

x = np.random.uniform(0.0, L, size=(num_samples, 1))
t = np.random.uniform(start, end, size=(num_samples, 1))

x_test = tf.convert_to_tensor(x, dtype=tf.float32)
t_test = tf.convert_to_tensor(t, dtype=tf.float32)

# %%
u_pred = model(tf.concat([x, t], axis=1)).numpy()

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x, t, u_pred)

ax.set_xlabel('x axis')
ax.set_ylabel('t axis')
ax.set_zlabel('u axis')

plt.show()

# %%
u = np.sin(np.pi * x) * np.exp((-alpha * (np.pi ** 2)) * t)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x, t, u)

ax.set_xlabel('x axis')
ax.set_ylabel('t axis')
ax.set_zlabel('u axis')

plt.show()

# %%
print(f"MAE: {np.mean(np.abs(u - u_pred))}")
# Out:
# MAE: 0.029407510609274636

# %% [markdown]
# ## Подытог обучения модели с помощью RMSprop
#
# За 6000 эпох:
#
# *   train total loss: 0.000902
# *   test MAE: 0.029407510609274636
